# %% [markdown]
# # Estatistica PowerQuery
#
# Caso queira trazer a "saúde" da sua base, com a quantidade de linhas, valor máximo, mínimo, média, valores distintos e etc, usar o **Table.Profile** em uma consulta nula atende suas expectativas.
#
# Isso pode ser feito em duas etapas:
#
# 1) Criar uma consulta nula *(em branco)* :
# 2) inserir = `Table.Profile(nome_tabela)`
#
# Abaixo está o código fonte

# %%
let
    Fonte = Table.Profile(f_Razao_IFS)
in
    Fonte
