# %% [markdown]
# <a href="https://colab.research.google.com/github/arthurweslen/PowerQuery_DAX/blob/main/DAX/HTML_Dica_de_Ferramenta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Criar uma dica de ferramenta com HTML
#
# 1) Baixe o vitual HTML Content
# 2) Criar uma medida DAX usando códigos HTML
# 3) Colocar em uma aba nova, permitindo como dica de ferramenta'

# %% [markdown]
# 1)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dica de Ferramenta DRE =
# VAR LINHADRE = SELECTEDVALUE(d_Mascara_DRE[Rótulos de Linha])
# VAR AGRP2 = SELECTEDVALUE(d_Plano_de_Contas[Agrupamento Conta Contábil Grau 2])
# VAR AGRP3 = SELECTEDVALUE(d_Plano_de_Contas[Agrupamento Conta Contábil Grau 3])
# VAR PCTCONTAS = SELECTEDVALUE(d_Plano_de_Contas[Pacote de Contas])
# VAR CONTACONTABIL = SELECTEDVALUE(d_Plano_de_Contas[Nome Conta Contábil IFS])
# VAR NOME = SELECTEDVALUE(f_Resultado_Consolidado[Nome])
# VAR N_REF = SELECTEDVALUE(f_Resultado_Consolidado[N_Ref])
# VAR TEXTO = SELECTEDVALUE(f_Resultado_Consolidado[Texto])
# VAR NUMPO = SELECTEDVALUE(f_Resultado_Consolidado[Numero_Po])
# RETURN
# "
# <div style='
#     font-family:Segoe UI;
#     padding:10px;
#     border-radius:8px;
#     background-color:#f9f9f9;
#     box-shadow:0 2px 6px rgba(0,0,0,0.1);
#     width:250px;
# '>
#
#     <div style='
#         font-size:14px;
#         font-weight:bold;
#         color:#2E86C1;
#         margin-bottom:8px;
#     '>
#         📊 Detalhes DRE
#     </div>
#
#     <div style='margin-bottom:6px'>
#         <span style='color:#555'><b>Linha:</b></span><br>
#         <span style='color:#000'>" & LINHADRE & "</span>
#     </div>
#
#     <div style='margin-bottom:6px'>
#         <span style='color:#555'><b>Agrp Conta Contábil Grau 2:</b></span><br>
#         <span style='color:#000'>" & AGRP2 & "</span>
#     </div>
#
#     <div>
#         <span style='color:#555'><b>Agrp Conta Contábil Grau 3:</b></span><br>
#         <span style='color:#000'>" & AGRP3 & "</span>
#     </div>
#
#     <div>
#         <span style='color:#555'><b>Pacote de Contas:</b></span><br>
#         <span style='color:#000'>" & PCTCONTAS & "</span>
#     </div>
#
#     <div>
#         <span style='color:#555'><b>Conta Contábil:</b></span><br>
#         <span style='color:#000'>" & CONTACONTABIL & "</span>
#     </div>
#
#     <div>
#         <span style='color:#555'><b>Nome:</b></span><br>
#         <span style='color:#000'>" & NOME & "</span>
#     </div>
#
#     <div>
#         <span style='color:#555'><b>N_REF:</b></span><br>
#         <span style='color:#000'>" & N_REF & "</span>
#     </div>
#
#     <div>
#         <span style='color:#555'><b>Texto:</b></span><br>
#         <span style='color:#000'>" & TEXTO & "</span>
#     </div>
#
#     <div>
#         <span style='color:#555'><b>Número PO:</b></span><br>
#         <span style='color:#000'>" & NUMPO & "</span>
#     </div>
#
# </div>
# "

# %% [markdown]
# ![image.png](data:image/png;base64,...)
